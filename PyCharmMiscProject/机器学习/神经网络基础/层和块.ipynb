# %%
import  torch
from  torch import  nn
from torch.nn import functional as F

# %%
net=nn.Sequential(nn.Linear(20,256),nn.ReLU(),nn.Linear(256,10))

X=torch.rand(2,20)
net(X)
# Out:
# tensor([[ 0.1376,  0.1855,  0.0340,  0.0049, -0.0933, -0.1504,  0.0263,  0.2861,
#           0.2351,  0.0382],
#         [ 0.1869,  0.2238,  0.0964, -0.0279, -0.1127, -0.1016, -0.0967,  0.1004,
#           0.0937, -0.1838]], grad_fn=<AddmmBackward0>)
